# %% [markdown]
# ### some imports

# %%
# !pip install langchain langchain-core langchain-community pydantic duckduckgo-search
# Out:
# Requirement already satisfied: langchain in C:\DataScience\venv\Lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in C:\DataScience\venv\Lib\site-packages (1.3.2)
# Requirement already satisfied: langchain-community in C:\DataScience\venv\Lib\site-packages (0.4.1)
# Requirement already satisfied: pydantic in C:\DataScience\venv\Lib\site-packages (2.12.4)
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in C:\DataScience\venv\Lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (0.0.14)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (0.7.31)
# Requirement already satisfied: packaging>=23.2.0 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\DataScience\venv\Lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\DataScience\venv\Lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\DataScience\venv\Lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\DataScience\venv\Lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in C:\DataScience\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\DataScience\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in C:\DataScience\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\DataScience\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in C:\DataScience\venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\DataScience\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\DataScience\venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\DataScience\venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\DataScience\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\DataScience\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\DataScience\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in C:\DataScience\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.9.0)
# Requirement already satisfied: certifi in C:\DataScience\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\DataScience\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\DataScience\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in C:\DataScience\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in C:\DataScience\venv\Lib\site-packages (from langchain-community) (1.0.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\DataScience\venv\Lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\DataScience\venv\Lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in C:\DataScience\venv\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\DataScience\venv\Lib\site-packages (from langchain-community) (2.14.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\DataScience\venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in C:\DataScience\venv\Lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\DataScience\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\DataScience\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\DataScience\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\DataScience\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\DataScience\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\DataScience\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\DataScience\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\DataScience\venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\DataScience\venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\DataScience\venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\DataScience\venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\DataScience\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\DataScience\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.4.0)
# Requirement already satisfied: greenlet>=1 in C:\DataScience\venv\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\DataScience\venv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: click>=8.1.8 in C:\DataScience\venv\Lib\site-packages (from duckduckgo-search) (8.2.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-1.2.3-cp310-abi3-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: lxml>=5.3.0 in C:\DataScience\venv\Lib\site-packages (from duckduckgo-search) (6.0.1)
# Requirement already satisfied: colorama in C:\DataScience\venv\Lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in C:\DataScience\venv\Lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.1)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading primp-1.2.3-cp310-abi3-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.9 MB 672.2 kB/s eta 0:00:05
#    -------- ------------------------------- 0.8/3.9 MB 671.3 kB/s eta 0:00:05
#    -------- ------------------------------- 0.8/3.9 MB 671.3 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.9 MB 699.0 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/3.9 MB 699.0 kB/s eta 0:00:05
#    ------------- -------------------------- 1.3/3.9 MB 713.8 kB/s eta 0:00:04
#    ---------------- ----------------------- 1.6/3.9 MB 735.9 kB/s eta 0:00:04
#    ------------------ --------------------- 1.8/3.9 MB 756.9 kB/s eta 0:00:03
#    ------------------ --------------------- 1.8/3.9 MB 756.9 kB/s eta 0:00:03
#    --------------------- ------------------ 2.1/3.9 MB 767.8 kB/s eta 0:00:03
#    ------------------------ --------------- 2.4/3.9 MB 789.6 kB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.9 MB 807.4 kB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.9 MB 807.4 kB/s eta 0:00:02
#    ----------------------------- ---------- 2.9/3.9 MB 822.5 kB/s eta 0:00:02
#    -------------------------------- ------- 3.1/3.9 MB 839.0 kB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.9 MB 853.2 kB/s eta 0:00:01
#    ------------------------------------- -- 3.7/3.9 MB 868.9 kB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 878.7 kB/s  0:00:05
# Installing collected packages: primp, duckduckgo-search
#
#    -------------------- ------------------- 1/2 [duckduckgo-search]
#    ---------------------------------------- 2/2 [duckduckgo-search]
#
# Successfully installed duckduckgo-search-8.1.1 primp-1.2.3

# %% [markdown]
# # DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGo
